# %%
import os 
import json
import pandas as pd
import traceback

# %%
pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (0.3.74)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.12.15-cp310-cp310-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (0.4.13)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-community) (2.2.6)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.7.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.6.4-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.3.2-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.20.1-cp310-cp310-win_amd64.whl.metadata (76 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from requests<3,>=2->langchain-community) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\envs\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\envs\env\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 6.6 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 5.2 MB/s eta 0:00:00
# Downloading aiohttp-3.12.15-cp310-cp310-win_amd64.whl (452 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.4-cp310-cp310-win_amd64.whl (46 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.1-cp310-cp310-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp310-cp310-win_amd64.whl (43 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.3.2-cp310-cp310-win_amd64.whl (41 kB)
# Installing collected packages: propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-community
#
#    -------- -------------------------------  3/14 [marshmallow]
#    ----------- ----------------------------  4/14 [httpx-sse]
#    -------------------- -------------------  7/14 [yarl]
#    ---------------------------- ----------- 10/14 [pydantic-settings]
#    ---------------------------- ----------- 10/14 [pydantic-settings]
#    ------------------------------- -------- 11/14 [dataclasses-json]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [aiohttp]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ------------------------------------- -- 13/14 [langchain-community]
#    ---------------------------------------- 14/14 [langchain-community]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 dataclasses-json-0.6.7 frozenlist-1.7.0 httpx-sse-0.4.1 langchain-community-0.3.27 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 propcache-0.3.2 pydantic-settings-2.10.1 typing-inspect-0.9.0 yarl-1.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.29-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.74 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-openai) (0.3.74)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-openai) (1.99.9)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.11.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.4.13)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\envs\env\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai) (3.10)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\envs\env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\envs\env\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.4.1)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai)
#   Downloading regex-2025.7.34-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.4)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.74->langchain-openai) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\env\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\env\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.86.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-0.3.29-py3-none-any.whl (74 kB)
# Downloading tiktoken-0.11.0-cp310-cp310-win_amd64.whl (884 kB)
#    ---------------------------------------- 0.0/884.2 kB ? eta -:--:--
#    ---------------------------------------- 884.2/884.2 kB 5.0 MB/s eta 0:00:00
# Downloading regex-2025.7.34-cp310-cp310-win_amd64.whl (276 kB)
# Installing collected packages: regex, tiktoken, langchain-openai
#
#    ---------------------------------------- 0/3 [regex]
#    -------------------------- ------------- 2/3 [langchain-openai]
#    ---------------------------------------- 3/3 [langchain-openai]
#
# Successfully installed langchain-openai-0.3.29 regex-2025.7.34 tiktoken-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI

# %%
import os
from dotenv import load_dotenv

# Load variables from .env
load_dotenv()

# Retrieve the API key
# Out:
# True

# %%
KEY = os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm = ChatOpenAI(
    openai_api_key=KEY,
    model="gpt-3.5-turbo",
    temperature=0.5,
    max_tokens=1000,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)
